# %% [markdown]
# # Reading data

# %%
import pandas as pd

#read the data 
dataset = pd.read_csv("data.csv")

#view data 
dataset
# Out:
#                                                 comment        type
# 0                                          يعطيكم الصحة      normal
# 1                                       عشي عندهما رجال      normal
# 2                            نبيك مغتصب الاطفال المنيوك  aggressive
# 3     بشير فار حبس خارج ثالثة ابتيدائي جاي اتناقش ما...      normal
# 4     مول القناة دزيزي جنيت تفرجت الفديو تاعك ولدي ت...      normal
# ...                                                 ...         ...
# 4401  مممتلكت مممتلكت تتحدثون عاليه مرتن تقول ايمام ...      normal
# 4402                 ربي يلعنو رئيس تونس الخنزير بففففف  aggressive
# 4403  قولك اننا لسنا عرب ههههه اذهبي للمخبر حليلي جي...  aggressive
# 4404  علاقة للتحرش باللباس الدول لتي تبيح الحرية الج...      normal
# 4405                         لطفي العبدلي خير ألحق بارك      normal
#
# [4406 rows x 2 columns]

# %%
pip install emoji
# Out:
# Collecting emojiNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/96/c6/0114b2040a96561fd1b44c75df749bbd3c898bf8047fb5ce8d7590d2dee6/emoji-2.8.0-py2.py3-none-any.whl.metadata
#   Downloading emoji-2.8.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#    ---------------------------------------- 0.0/358.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/358.9 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/358.9 kB 660.6 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/358.9 kB 393.8 kB/s eta 0:00:01
#    ------ -------------------------------- 61.4/358.9 kB 469.7 kB/s eta 0:00:01
#    ------ -------------------------------- 61.4/358.9 kB 469.7 kB/s eta 0:00:01
#    ------ -------------------------------- 61.4/358.9 kB 469.7 kB/s eta 0:00:01
#    ------ -------------------------------- 61.4/358.9 kB 469.7 kB/s eta 0:00:01
#    ------ -------------------------------- 61.4/358.9 kB 469.7 kB/s eta 0:00:01
#    ------------- ------------------------ 122.9/358.9 kB 313.8 kB/s eta 0:00:01
#    ------------- ------------------------ 122.9/358.9 kB 313.8 kB/s eta 0:00:01
#    ------------------- ------------------ 184.3/358.9 kB 371.2 kB/s eta 0:00:01
#    --------------------- ---------------- 204.8/358.9 kB 402.0 kB/s eta 0:00:01
#    ------------------------ ------------- 235.5/358.9 kB 400.1 kB/s eta 0:00:01
#    ------------------------ ------------- 235.5/358.9 kB 400.1 kB/s eta 0:00:01
#    ------------------------ ------------- 235.5/358.9 kB 400.1 kB/s eta 0:00:01
#    ------------------------ ------------- 235.5/358.9 kB 400.1 kB/s eta 0:00:01
#    ---------------------------- --------- 266.2/358.9 kB 334.2 kB/s eta 0:00:01
#    --------------------------------- ---- 317.4/358.9 kB 377.9 kB/s eta 0:00:01
#    -------------------------------------  358.4/358.9 kB 405.3 kB/s eta 0:00:01
#    -------------------------------------  358.4/358.9 kB 405.3 kB/s eta 0:00:01
#    -------------------------------------  358.4/358.9 kB 405.3 kB/s eta 0:00:01
#    -------------------------------------- 358.9/358.9 kB 365.8 kB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0

# %%
# Required libraries
import emoji
import nltk
nltk.download('stopwords')
stop = set(nltk.corpus.stopwords.words("arabic"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Text length analysis 
def avg_word(sentence):
    words = sentence.split()
    if len(words) == 0:
        return 0
    return (sum(len(word) for word in words)/len(words))

# %%
# Counting emoji
def emoji_counter(sentence):
    return emoji.emoji_count(sentence)

# %%
dataset['word_count'] = dataset['comment'].apply(lambda x: len(str(x).split(" ")))
dataset['char_count'] = dataset['comment'].str.len() ## this also includes spaces
dataset['avg_char_per_word'] = dataset['comment'].apply(lambda x: avg_word(x))
#stop = stopwords.words('arabic')
dataset['stopwords'] = dataset['comment'].apply(lambda x: len([x for x in x.split() if x in stop]))
dataset['emoji_count'] = dataset['comment'].apply(lambda x: emoji_counter(x))
dataset = dataset.sort_values(by='word_count',ascending=[0])
dataset.head()
# Out:
#                                                 comment        type  \
# 140   صديقتي أمال اقرئي تعليقي سمحتي صدقيني صدقيني ا...      normal
# 752   فاهمة كيفف ربي نظملهم حياتهم وراهم الطريق الصح...      normal
# 2532  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...  aggressive
# 3155  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...  aggressive
# 3750  اشد اعداء الاسلام انزل محمد يسمون بمفتيين وعلم...  aggressive
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count
# 140          388        2515           5.484536          5            0
# 752          234        1442           5.166667          0            0
# 2532         207        1349           5.521739          0            0
# 3155         207        1349           5.521739          0            0
# 3750         173        1020           4.901734          7            0

# %%
# Overall averages of each numeric column 
dataset_stat = dataset.mean(axis=0)
dataset_stat
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_7812\124873177.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset_stat = dataset.mean(axis=0)
# word_count           12.123468
# char_count           72.245574
# avg_char_per_word     4.945104
# stopwords             0.038357
# emoji_count           0.000000
# dtype: float64

# %% [markdown]
# # text Preprocessing

# %%
stop = set(nltk.corpus.stopwords.words("arabic"))
nltk.download('punkt')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#remove stop words
def stopRemoval(text):
    temptweet = word_tokenize(text)
    text = " ".join([w for w in temptweet if not w in stop and len(w) >= 2])
    return text

# %%
dataset['noStop_comment'] = dataset['comment'].apply(lambda x:stopRemoval(x))
dataset
# Out:
#                                                 comment        type  \
# 140   صديقتي أمال اقرئي تعليقي سمحتي صدقيني صدقيني ا...      normal
# 752   فاهمة كيفف ربي نظملهم حياتهم وراهم الطريق الصح...      normal
# 2532  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...  aggressive
# 3155  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...  aggressive
# 3750  اشد اعداء الاسلام انزل محمد يسمون بمفتيين وعلم...  aggressive
# ...                                                 ...         ...
# 322                                               اوهدي      normal
# 320                                                  طز  aggressive
# 1981                                             ترهدين      normal
# 1995                                                تقو  aggressive
# 1807                                              واطية  aggressive
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 140          388        2515           5.484536          5            0
# 752          234        1442           5.166667          0            0
# 2532         207        1349           5.521739          0            0
# 3155         207        1349           5.521739          0            0
# 3750         173        1020           4.901734          7            0
# ...          ...         ...                ...        ...          ...
# 322            1           5           5.000000          0            0
# 320            1           2           2.000000          0            0
# 1981           1           6           6.000000          0            0
# 1995           1           3           3.000000          0            0
# 1807           1           5           5.000000          0            0
#
#                                          noStop_comment
# 140   صديقتي أمال اقرئي تعليقي سمحتي صدقيني صدقيني ا...
# 752   فاهمة كيفف ربي نظملهم حياتهم وراهم الطريق الصح...
# 2532  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...
# 3155  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...
# 3750  اشد اعداء الاسلام انزل محمد يسمون بمفتيين وعلم...
# ...                                                 ...
# 322                                               اوهدي
# 320                                                  طز
# 1981                                             ترهدين
# 1995                                                تقو
# 1807                                              واطية
#
# [4406 rows x 8 columns]

# %%
# Required libraries
import re

def normalize(text):
    # remove three or more repetitions of any character
    pattern = re.compile(r"(.)\1{2,}", re.DOTALL)
    text=pattern.sub(r"\1\1", text)
    # normalize alif
    text = text.replace(u"\u0625", u"\u0627")  # HAMZA below, with LETTER ALEF
    text = text.replace(u"\u0622", u"\u0627")  # ALEF WITH MADDA ABOVE, with LETTER ALEF
    text = text.replace(u"\u0623", u"\u0627")  # ALEF WITH HAMZA ABOVE, with LETTER ALEF
    # normalize taa
    text=text.replace(u"\u0629", u"\u0647") # taa' marbuuTa, with haa'
    # normalize yaa
    text = text.replace(u"\u064A", u"\u0649")  # yaa' with 'alif maqSuura
    # remove diacritics 
    text = text.replace(u"\u064B", "")  # fatHatayn
    text = text.replace(u"\u064C", "")  # Dammatayn
    text = text.replace(u"\u064D", "")  # kasratayn
    text = text.replace(u"\u064E", "")  # fatHa
    text = text.replace(u"\u064F", "")  # Damma
    text = text.replace(u"\u0650", "")  # kasra
    text = text.replace(u"\u0651", "")  # shaddah
    text = text.replace(u"\u0652", "")  # sukuun
    text = text.replace(u"\u0670", "`")  # dagger 'alif
    return text

# %%
dataset['normalized_comment'] = dataset['comment'].apply(lambda x: normalize(x))

# aggregate all preprocessing steps into one column for the next step
dataset['text'] = dataset['noStop_comment'].apply(lambda x:normalize(x))

dataset.head()
# Out:
#                                                 comment        type  \
# 140   صديقتي أمال اقرئي تعليقي سمحتي صدقيني صدقيني ا...      normal
# 752   فاهمة كيفف ربي نظملهم حياتهم وراهم الطريق الصح...      normal
# 2532  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...  aggressive
# 3155  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...  aggressive
# 3750  اشد اعداء الاسلام انزل محمد يسمون بمفتيين وعلم...  aggressive
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 140          388        2515           5.484536          5            0
# 752          234        1442           5.166667          0            0
# 2532         207        1349           5.521739          0            0
# 3155         207        1349           5.521739          0            0
# 3750         173        1020           4.901734          7            0
#
#                                          noStop_comment  \
# 140   صديقتي أمال اقرئي تعليقي سمحتي صدقيني صدقيني ا...
# 752   فاهمة كيفف ربي نظملهم حياتهم وراهم الطريق الصح...
# 2532  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...
# 3155  اعتقد صهيونى امريكى جاسوس الغرب يريد التجنيس ب...
# 3750  اشد اعداء الاسلام انزل محمد يسمون بمفتيين وعلم...
#
#                                      normalized_comment  \
# 140   صدىقتى امال اقرئى تعلىقى سمحتى صدقىنى صدقىنى ا...
# 752   فاهمه كىفف ربى نظملهم حىاتهم وراهم الطرىق الصح...
# 2532  اعتقد صهىونى امرىكى جاسوس الغرب ىرىد التجنىس ب...
# 3155  اعتقد صهىونى امرىكى جاسوس الغرب ىرىد التجنىس ب...
# 3750  اشد اعداء الاسلام انزل محمد ىسمون بمفتىىن وعلم...
#
#                                                    text
# 140   صدىقتى امال اقرئى تعلىقى سمحتى صدقىنى صدقىنى ا...
# 752   فاهمه كىفف ربى نظملهم حىاتهم وراهم الطرىق الصح...
# 2532  اعتقد صهىونى امرىكى جاسوس الغرب ىرىد التجنىس ب...
# 3155  اعتقد صهىونى امرىكى جاسوس الغرب ىرىد التجنىس ب...
# 3750  اشد اعداء الاسلام انزل محمد ىسمون بمفتىىن وعلم...

# %%
# Required libraries
import string 
import re

# %%
arabicPunctuations = [".","`","؛","<",">","(",")","*","&","^","%","]","[",",","ـ","،","/",":","؟",".","'","{","}","~","|","!","”","…","“","–"] # defining customized punctuation marks
englishPunctuations = string.punctuation # importing English punctuation marks
englishPunctuations = [word.strip() for word in englishPunctuations] # converting the English punctuation from a string to array for processing
punctuationsList = arabicPunctuations + englishPunctuations # creating a list of all punctuation marks

# %%
def removingPunctuation(text):
  cleancomment = ''
  for i in text:
    if i not in arabicPunctuations:
      cleancomment = cleancomment + '' + i 
  return cleanTweet

# %%
dataset['noPunc_comment'] = dataset['comment'].apply(lambda x: removingPunctuation(x))
dataset['text'] = dataset['text'].apply(lambda x: removingPunctuation(x))

dataset.sample(5)
# Out:
#                                                 comment        type  \
# 2110                  خانو ثورة جزائرية حرك ساعدو فرنسا      normal
# 1174  أولا تفهموني خطأ منهج العجوز المميع الفتى الخا...      normal
# 973   حبيت الضحك الناس شمس الدين باشا اخي طلعت نايك ...  aggressive
# 514   اخبار تفيد البلاد تخدم بمبريم دباغ عصبة وولشمس...  aggressive
# 674   ربي يهدي وجهة رايي الدين الدين الاسلام بجبوج ك...  aggressive
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 2110           6          33           4.666667          0            0
# 1174          25         145           4.840000          0            0
# 973           11          56           4.181818          0            0
# 514           11          69           5.363636          0            0
# 674           10          55           4.600000          0            0
#
#                                          noStop_comment  \
# 2110                  خانو ثورة جزائرية حرك ساعدو فرنسا
# 1174  أولا تفهموني خطأ منهج العجوز المميع الفتى الخا...
# 973   حبيت الضحك الناس شمس الدين باشا اخي طلعت نايك ...
# 514   اخبار تفيد البلاد تخدم بمبريم دباغ عصبة وولشمس...
# 674   ربي يهدي وجهة رايي الدين الدين الاسلام بجبوج ك...
#
#                                      normalized_comment  \
# 2110                  خانو ثوره جزائرىه حرك ساعدو فرنسا
# 1174  اولا تفهمونى خطا منهج العجوز الممىع الفتى الخا...
# 973   حبىت الضحك الناس شمس الدىن باشا اخى طلعت ناىك ...
# 514   اخبار تفىد البلاد تخدم بمبرىم دباغ عصبه وولشمس...
# 674   ربى ىهدى وجهه راىى الدىن الدىن الاسلام بجبوج ك...
#
#                                                    text  \
# 2110                  خانو ثوره جزائرىه حرك ساعدو فرنسا
# 1174  اولا تفهمونى خطا منهج العجوز الممىع الفتى الخا...
# 973   حبىت الضحك الناس شمس الدىن باشا اخى طلعت ناىك ...
# 514   اخبار تفىد البلاد تخدم بمبرىم دباغ عصبه وولشمس...
# 674   ربى ىهدى وجهه راىى الدىن الدىن الاسلام بجبوج ك...
#
#                                          noPunc_comment
# 2110                  خانو ثورة جزائرية حرك ساعدو فرنسا
# 1174  أولا تفهموني خطأ منهج العجوز المميع الفتى الخا...
# 973   حبيت الضحك الناس شمس الدين باشا اخي طلعت نايك ...
# 514   اخبار تفيد البلاد تخدم بمبريم دباغ عصبة وولشمس...
# 674   ربي يهدي وجهة رايي الدين الدين الاسلام بجبوج ك...

# %%
def clean(text):
    # Remove extra whitespace
    text = re.sub('\s+', ' ', text)  
    # Remove numbers
    text = re.sub("\d+", " ", text)
    return text

# %%
dataset['clean_comment'] = dataset['comment'].apply(lambda x:clean(x))
dataset['text'] = dataset['text'].apply(lambda x:clean(x))

# %%
dataset.sample(5)
# Out:
#                                                 comment        type  \
# 4284  مريم الدباغ تمثل تكذب روحها تقول علاها فلوس حر...      normal
# 2877  لاكان جات إسرائيل تحكم تونس ومصر عاشين العلم و...      normal
# 3104    الت عد حدود سينتشر الفقر المتقع الأوبئة المبيدة      normal
# 2464  هههههه وتجيب اختك تستمتع بلعق الزب التونسي الم...  aggressive
# 1269                  حاسيت مريم رافت الهجان هههههههههه      normal
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 4284          16          90           4.687500          0            0
# 2877          17         129           6.647059          0            0
# 3104           8          47           5.000000          0            0
# 2464           8          50           5.375000          0            0
# 1269           5          33           5.800000          0            0
#
#                                          noStop_comment  \
# 4284  مريم الدباغ تمثل تكذب روحها تقول علاها فلوس حر...
# 2877  لاكان جات إسرائيل تحكم تونس ومصر عاشين العلم و...
# 3104    الت عد حدود سينتشر الفقر المتقع الأوبئة المبيدة
# 2464  هههههه وتجيب اختك تستمتع بلعق الزب التونسي الم...
# 1269                  حاسيت مريم رافت الهجان هههههههههه
#
#                                      normalized_comment  \
# 4284  مرىم الدباغ تمثل تكذب روحها تقول علاها فلوس حر...
# 2877  لاكان جات اسرائىل تحكم تونس ومصر عاشىن العلم و...
# 3104    الت عد حدود سىنتشر الفقر المتقع الاوبئه المبىده
# 2464     هه وتجىب اختك تستمتع بلعق الزب التونسى المحرحر
# 1269                          حاسىت مرىم رافت الهجان هه
#
#                                                    text  \
# 4284  مرىم الدباغ تمثل تكذب روحها تقول علاها فلوس حر...
# 2877  لاكان جات اسرائىل تحكم تونس ومصر عاشىن العلم و...
# 3104    الت عد حدود سىنتشر الفقر المتقع الاوبئه المبىده
# 2464     هه وتجىب اختك تستمتع بلعق الزب التونسى المحرحر
# 1269                          حاسىت مرىم رافت الهجان هه
#
#                                          noPunc_comment  \
# 4284  مريم الدباغ تمثل تكذب روحها تقول علاها فلوس حر...
# 2877  لاكان جات إسرائيل تحكم تونس ومصر عاشين العلم و...
# 3104    الت عد حدود سينتشر الفقر المتقع الأوبئة المبيدة
# 2464  هههههه وتجيب اختك تستمتع بلعق الزب التونسي الم...
# 1269                  حاسيت مريم رافت الهجان هههههههههه
#
#                                           clean_comment
# 4284  مريم الدباغ تمثل تكذب روحها تقول علاها فلوس حر...
# 2877  لاكان جات إسرائيل تحكم تونس ومصر عاشين العلم و...
# 3104    الت عد حدود سينتشر الفقر المتقع الأوبئة المبيدة
# 2464  هههههه وتجيب اختك تستمتع بلعق الزب التونسي الم...
# 1269                  حاسيت مريم رافت الهجان هههههههههه

# %% [markdown]
# # Preparing dataset

# %%
# required libraries
import pandas as pd
import csv
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
# shuffle will help to reduce bias
dataset = shuffle(dataset)

# 20% test set and 80% train set
train, test = train_test_split(dataset, test_size=0.2,random_state=42)
train
# Out:
#                                                 comment        type  \
# 594   العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...  aggressive
# 3482                           تشعة وشبعين هههههههههههه      normal
# 852   الرايس العجوز الكلب الشعب اخرج ملت محمد خطر ال...  aggressive
# 2586  فيصل خالد احسن بردت قلبي ليبيه وأكره تونس بلد ...  aggressive
# 3119                                جبري داير روحك تفهم  aggressive
# ...                                                 ...         ...
# 2850    والله حوال بلاد دخلت حيط والباحي يضحك فردا فردا      normal
# 1226               تونس القدم معروفة بجمال البنات العهر  aggressive
# 942   مخيب وجهها بصراحة فهمتش تعمل حياتها ولات التلا...  aggressive
# 840   حسبنا ونعما الوكيل شعب جاااااااااهل بدينه مارح...  aggressive
# 4158  راجل شمس الدين وسيد الرجال وفحل وعاقل ولد الفا...      normal
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 594           16          96           5.062500          0            0
# 3482           3          24           7.333333          0            0
# 852            9          51           4.777778          0            0
# 2586          17         102           5.058824          0            0
# 3119           4          19           4.000000          0            0
# ...          ...         ...                ...        ...          ...
# 2850           9          47           4.333333          0            0
# 1226           6          36           5.166667          0            0
# 942            9          58           5.555556          0            0
# 840           23         151           5.608696          0            0
# 4158          11          63           4.818182          0            0
#
#                                          noStop_comment  \
# 594   العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...
# 3482                           تشعة وشبعين هههههههههههه
# 852   الرايس العجوز الكلب الشعب اخرج ملت محمد خطر ال...
# 2586  فيصل خالد احسن بردت قلبي ليبيه وأكره تونس بلد ...
# 3119                                جبري داير روحك تفهم
# ...                                                 ...
# 2850    والله حوال بلاد دخلت حيط والباحي يضحك فردا فردا
# 1226               تونس القدم معروفة بجمال البنات العهر
# 942   مخيب وجهها بصراحة فهمتش تعمل حياتها ولات التلا...
# 3967  رجل الاعمال معاک بو عصبة موناکو ننصحک بشلاکة ش...  aggressive
# 2823  ربي هبط يحاسب جبريل يطلع جبرين بو ستميات جناح ...  aggressive
# 3748  نشكرها صراحتها منافقة إنسان عندو حاجات فحياتو ...      normal
# 2327  البعرة الملحد يتطاول حكام كفرة فجرة اللعنة الد...  aggressive
# 3677                                             مسلمين      normal
# ...                                                 ...         ...
# 227                                                كرثة      normal
# 485   يعطك عصبة دورت الموضوع للناس عصبة راسك وراسهم ...  aggressive
# 64    العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...  aggressive
# 1100                أفكار بوركابية علمانية شكرا اردوكان      normal
# 1413             والله وبالله وتالله نكرهك مايا أشد كره  aggressive
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 3967          27         139           4.185185          0            0
# 2823          12          64           4.416667          0            0
# 3748          20         124           5.250000          0            0
# 2327          20         124           5.250000          0            0
# 3677           1           6           6.000000          0            0
# ...          ...         ...                ...        ...          ...
# 227            1           4           4.000000          0            0
# 485           22         120           4.500000          0            0
# 64            16          96           5.062500          0            0
# 1100           5          35           6.200000          0            0
# 1413           7          38           4.571429          0            0
#
#                                          noStop_comment  \
# 3967  رجل الاعمال معاک بو عصبة موناکو ننصحک بشلاکة ش...
# 2823  ربي هبط يحاسب جبريل يطلع جبرين بو ستميات جناح ...
# 3748  نشكرها صراحتها منافقة إنسان عندو حاجات فحياتو ...
# 2327  البعرة الملحد يتطاول حكام كفرة فجرة اللعنة الد...
# 3677                                             مسلمين
# ...                                                 ...
# 227                                                كرثة
# 485   يعطك عصبة دورت الموضوع للناس عصبة راسك وراسهم ...
# 64    العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...
# 1100                أفكار بوركابية علمانية شكرا اردوكان
# 1413             والله وبالله وتالله نكرهك مايا أشد كره
#
#                                      normalized_comment  \
# 3967  رجل الاعمال معاک بو عصبه موناکو ننصحک بشلاکه ش...
# 2823  ربى هبط ىحاسب جبرىل ىطلع جبرىن بو ستمىات جناح ...
# 3748  نشكرها صراحتها منافقه انسان عندو حاجات فحىاتو ...
# 2327  البعره الملحد ىتطاول حكام كفره فجره اللعنه الد...
# 3677                                             مسلمىن
# ...                                                 ...
# 227                                                كرثه
# 485   ىعطك عصبه دورت الموضوع للناس عصبه راسك وراسهم ...
# 64    العبو العبو لعنه كانهم لىسو مجاورىن الجزائر وا...
# 1100                افكار بوركابىه علمانىه شكرا اردوكان
# 1413             والله وبالله وتالله نكرهك ماىا اشد كره
#
#                                                    text  \
# 3967  رجل الاعمال معاک بو عصبه موناکو ننصحک بشلاکه ش...
# 2823  ربى هبط ىحاسب جبرىل ىطلع جبرىن بو ستمىات جناح ...
# 3748  نشكرها صراحتها منافقه انسان عندو حاجات فحىاتو ...
# 2327  البعره الملحد ىتطاول حكام كفره فجره اللعنه الد...
# 3677                                             مسلمىن
# ...                                                 ...
# 227                                                كرثه
# 485   ىعطك عصبه دورت الموضوع للناس عصبه راسك وراسهم ...
# 64    العبو العبو لعنه كانهم لىسو مجاورىن الجزائر وا...
# 1100                افكار بوركابىه علمانىه شكرا اردوكان
# 1413             والله وبالله وتالله نكرهك ماىا اشد كره
#
#                                          noPunc_comment  \
# 3967  رجل الاعمال معاک بو عصبة موناکو ننصحک بشلاکة ش...
# 2823  ربي هبط يحاسب جبريل يطلع جبرين بو ستميات جناح ...
# 3748  نشكرها صراحتها منافقة إنسان عندو حاجات فحياتو ...
# 2327  البعرة الملحد يتطاول حكام كفرة فجرة اللعنة الد...
# 3677                                             مسلمين
# ...                                                 ...
# 227                                                كرثة
# 485   يعطك عصبة دورت الموضوع للناس عصبة راسك وراسهم ...
# 64    العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...
# 1100                أفكار بوركابية علمانية شكرا اردوكان
# 1413             والله وبالله وتالله نكرهك مايا أشد كره
#
#                                           clean_comment
# 3967  رجل الاعمال معاک بو عصبة موناکو ننصحک بشلاکة ش...
# 2823  ربي هبط يحاسب جبريل يطلع جبرين بو ستميات جناح ...
# 3748  نشكرها صراحتها منافقة إنسان عندو حاجات فحياتو ...
# 2327  البعرة الملحد يتطاول حكام كفرة فجرة اللعنة الد...
# 3677                                             مسلمين
# ...                                                 ...
# 227                                                كرثة
# 485   يعطك عصبة دورت الموضوع للناس عصبة راسك وراسهم ...
# 64    العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...
# 1100                أفكار بوركابية علمانية شكرا اردوكان
# 1413             والله وبالله وتالله نكرهك مايا أشد كره
#
# [882 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(dataset, x='type')
plt.xlabel('Classes')
plt.ylabel('Number of occurrences')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(train, x='type')
plt.xlabel('Classes')
plt.ylabel('Number of occurrences')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(test, x='type')
plt.xlabel('Classes')
plt.ylabel('Number of occurrences')
plt.show()

# %%
# convert labels from categorical to numeric
label_map = {
    'normal' : 0,
    'aggressive': 1,
}

# %%
train['Offensive'] = train['type'].apply(lambda x: label_map[x])
test['Offensive'] = test['type'].apply(lambda x: label_map[x])

# %%
train
# Out:
#                                                 comment        type  \
# 594   العبو العبو لعنة كانهم ليسو مجاورين الجزائر وا...  aggressive
# 3482                           تشعة وشبعين هههههههههههه      normal
# 852   الرايس العجوز الكلب الشعب اخرج ملت محمد خطر ال...  aggressive
# 2586  فيصل خالد احسن بردت قلبي ليبيه وأكره تونس بلد ...  aggressive
# 3119                                جبري داير روحك تفهم  aggressive
# ...                                                 ...         ...
# 2850    والله حوال بلاد دخلت حيط والباحي يضحك فردا فردا      normal
# 1226               تونس القدم معروفة بجمال البنات العهر  aggressive
# 942   مخيب وجهها بصراحة فهمتش تعمل حياتها ولات التلا...  aggressive
# 840   حسبنا ونعما الوكيل شعب جاااااااااهل بدينه مارح...  aggressive
# 4158  راجل شمس الدين وسيد الرجال وفحل وعاقل ولد الفا...      normal
#
#       word_count  char_count  avg_char_per_word  stopwords  emoji_count  \
# 594           16          96           5.062500          0            0
# 3482           3          24           7.333333          0            0
# 852            9          51           4.777778          0            0
# 2586          17         102           5.058824          0            0
# 3119           4          19           4.000000          0            0
# ...          ...         ...                ...        ...          ...
# 2850           9          47           4.333333          0            0
# 1226           6          36           5.166667          0            0
# 852   الرايس العجوز الكلب الشعب اخرج ملت محمد خطر ال...          1
# 2586  فيصل خالد احسن بردت قلبي ليبيه وأكره تونس بلد ...          1
# 3119                                جبري داير روحك تفهم          1
# ...                                                 ...        ...
# 2850    والله حوال بلاد دخلت حيط والباحي يضحك فردا فردا          0
# 1226               تونس القدم معروفة بجمال البنات العهر          1
# 942   مخيب وجهها بصراحة فهمتش تعمل حياتها ولات التلا...          1
# 840   حسبنا ونعما الوكيل شعب جاااااااااهل بدينه مارح...          1
# 4158  راجل شمس الدين وسيد الرجال وفحل وعاقل ولد الفا...          0
#
# [3524 rows x 13 columns]

# %% [markdown]
# # Classification Model Development

# %%
# required libraries
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report

# %%
# Feature extraction
train_feature = train.text
train_target = train.Offensive

test_feature = test.text
test_target = test.Offensive

# %% [markdown]
# ## tfidf

# %%
# make pipeline (tdidf+logistic regression)
pipe = make_pipeline(TfidfVectorizer(),
                    LogisticRegression())

# make param grid
param_grid = {'logisticregression__C': [0.01, 0.1, 1, 10, 100]}

# create and fit the model
model = GridSearchCV(pipe, param_grid, cv=5)
model.fit(train_feature,train_target)

# make prediction and print accuracy
prediction = model.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy score is 0.88
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       443
#            1       0.87      0.89      0.88       439
#
#     accuracy                           0.88       882
#    macro avg       0.88      0.88      0.88       882
# weighted avg       0.88      0.88      0.88       882
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# make prediction and print accuracy
prediction = model.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# Accuracy score is 0.88
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       443
#            1       0.87      0.89      0.88       439
#
#     accuracy                           0.88       882
#    macro avg       0.88      0.88      0.88       882
# weighted avg       0.88      0.88      0.88       882

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]
normal_error
# Out:
#                                                 comment    type  word_count  \
# 3677                                             مسلمين  normal           1
# 4295  سي بسباس يبهت اليهود ماسكين السياحة تونس ردو ا...  normal          20
# 881               ماخذين باي محسوب المغرب عنصريين ههههه  normal           6
# 3237                     جايبنلي عبد الفتاح مورو للنقاش  normal           5
# 434                                          يسلم لسانك  normal           2
# 1645  بالرغم إنو شمس الدين ميعجبنيش بالصح والله راجل...  normal          15
# 861                                            عيب امين  normal           2
# 1910  تونس دولة مدنية دينية تحترم مواطنيها يهودا مسي...  normal          16
# 4057                  مايا المتعجرفه الخقوده متحبش افضل  normal           5
# 971   مستغرب شعب يسمع تفاهة شانو لى الدرجة الشعب تاف...  normal          20
# 1383  كريم عندو حق خير كلش يالجايحة كلمت الحق حبيتي ...  normal          18
# 4146                                    شاتي ربي يهدنيا  normal           3
# 3942                                       عيب شعب شقيق  normal           3
# 210                                 اقتلوهم انهم مرتزقة          1           0
# 619          شعب هوية كلمتين عربي وعشرة فرنساوي ههههههه          1           0
# 3321                مريم سامحيني خامجا لخماج زينك مولاش          1           0
# 2653  فاجرة زوالك وامثالك قريب بإذن علىأي تتكبرين تظ...          1           0
# 3444  لطفي شخص حقير وغير محترم وسمج شمس الدين باشا ر...          1           0
# 1931                                      ياخبيث ياملحد          1           0
# 1283  شايب ميبون لابس كوش ويبدل آيات واحنا مزلنا نتفرجو          1           0
# 3678  جيت مكان الشاب بشير نهز الكرسي نطيشو نشقلها راسها          1           0
# 435   العيب والله مسكينه جاتها فرصه بوهالي جايبها لل...          1           0
# 3375                                   ماخيبو لطفي صاقط          1           0
# 2957             لحبس شوي عدموهم يولو لخرين يخدمو قاعده          1           0
# 3727                                         عصبية إليك          1           0
# 43                   جزائرية تزني أبوها تقول بابا حواني          1           0
# 515                       شيطان الإنس بمصدق لكلام رسوله          1           0
# 4347                                         عصبية إليك          1           0
# 2710           صحيح ثقافتوا محدودة كلاشها زكها مالقتهاش          1           0
# 1884  جبري مخك ههههههههه وصلت للخارج ماوليتش انسان إ...          1           0
# 468                      مريم حشا اسمها وجها يشبه لترمة          1           0
# 2418  فيبلها متثقة المصفارة قالها عملت محاضرة جامعة ...          1           0
# 575                                 خنزيرة العياذ بالله          1           0
# 3253                            ک مازالت تبات جلال بریک          1           0
# 3890                              الأمازيغ عنصرين الكرب          1           0
# 574   تعرفو شمعناها مرأة الجزائر تعاملونها عاجزة عقل...          1           0
# 2526  يعاهر يولد دوله الدعاره والفسق تحني مسميين دول...          1           0
# 2553  قصف بدون هوية حمدلله عرب مسلمين باقون يهود بقا...          1           0
# 3436                                اقتلوهم انهم مرتزقة          1           0
# 767                       شيطان الإنس بمصدق لكلام رسوله          1           0
# 1326  جبتوه لطفي ملة قعرة ومنحبوش وميعجبنيش وبرنامجو...          1           0
# 3996  والله مافهمت هد العلة مقيمينها ماعندها حاجة ضي...          1           0
# 1527  لأصحاب البشرة السوداء الأفضل الذهاب تونس للدرا...          1           0
# 102   يكفرو يهدرو بكلام فاحش قاعدين ديار يديرو فيديو...          1           0
# 3949  لطفي شخص حقير وغير محترم وسمج شمس الدين باشا ر...          1           0
# 1810                          فائدة متخلق ومتخنث يهديكم          1           0

# %%
len(normal_error)
# Out:
# 59

# %%
len(aggressive_error)
# Out:
# 50

# %%
## make pipeline (tdidf+NB)

from sklearn.naive_bayes import MultinomialNB

# Create a pipeline
pipe1 = make_pipeline(TfidfVectorizer(), MultinomialNB())

# Define the parameter grid
param_grid1 = {'multinomialnb__alpha': [0.01, 0.1, 1, 10, 100]}

# Create and fit the model using grid search
model1 = GridSearchCV(pipe1, param_grid1, cv=5)
model1.fit(train_feature, train_target)

# make prediction and print accuracy
prediction = model1.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# Accuracy score is 0.85
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84       443
#            1       0.82      0.90      0.85       439
#
#     accuracy                           0.85       882
#    macro avg       0.85      0.85      0.85       882
# weighted avg       0.85      0.85      0.85       882

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified abusive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 89

# %%
len(aggressive_error)
# Out:
# 46

# %%
## make pipeline (tdidf+RandomForest)
from sklearn.ensemble import RandomForestClassifier

# Create the pipeline
pipe2 = make_pipeline(TfidfVectorizer(), RandomForestClassifier())

param_grid2 = {
    'randomforestclassifier__n_estimators': [100, 200, 300],
    'randomforestclassifier__max_depth': [None, 10, 20, 30]
}


# Create and fit the model using grid search
model2 = GridSearchCV(pipe2, param_grid2, cv=5)
model2.fit(train_feature, train_target)

# make prediction and print accuracy
prediction = model2.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# Accuracy score is 0.87
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88       443
#            1       0.93      0.81      0.86       439
#
#     accuracy                           0.87       882
#    macro avg       0.88      0.87      0.87       882
# weighted avg       0.88      0.87      0.87       882

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified abusive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 28

# %%
len(aggressive_error)
# Out:
# 85

# %%
## make pipeline (tdidf+SVM)
from sklearn.svm import LinearSVC  # Import LinearSVC

# Create a pipeline with TfidfVectorizer and LinearSVC
pipe3 = make_pipeline(TfidfVectorizer(), LinearSVC())

# Define the parameter grid for LinearSVC
param_grid3 = {'linearsvc__C': [0.01, 0.1, 1, 10, 100]}

# Create and fit the model using grid search
model3 = GridSearchCV(pipe3, param_grid3, cv=5)
model3.fit(train_feature, train_target)

# make prediction and print accuracy
prediction = model3.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Accuracy score is 0.87
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       443
#            1       0.86      0.89      0.87       439
#
#     accuracy                           0.87       882
#    macro avg       0.87      0.87      0.87       882
# weighted avg       0.87      0.87      0.87       882
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified abusive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 28

# %%
len(aggressive_error)
# Out:
# 85

# %%
#courbe roc 
#from sklearn.metrics import roc_curve, auc


# Get probability scores
#prob_scores = model.predict_proba(test_feature)
#prob_scores1 = model1.predict_proba(test_feature)
#prob_scores2 = model2.predict_proba(test_feature)
#prob_scores3 = model3.decision_function(test_feature)



# Calculate ROC curve metrics
#fpr, tpr, thresholds = roc_curve(test_target, prob_scores)
#roc_auc = roc_auc_score(test_target, prob_scores)## Calculate AUC 
#fpr1, tpr1, thresholds = roc_curve(test_target, prob_scores1)
#roc_auc1 = roc_auc_score(test_target, prob_scores1)## Calculate AUC 
#fpr2, tpr2, thresholds = roc_curve(test_target, prob_scores2)
#roc_auc2 = roc_auc_score(test_target, prob_scores2)## Calculate AUC 
#fpr3, tpr3, thresholds = roc_curve(test_target3, prob_scores)
#roc_auc3 = roc_auc_score(test_target, prob_scores3)## Calculate AUC 

# Plot the ROC curve
#plt.figure(figsize=(8, 6))
#plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve')
#plt.plot(fpr1, tpr1, color='darkblue', lw=2, label='ROC curve1')
#plt.plot(fpr2, tpr2, color='darkred', lw=2, label='ROC curve2')
#plt.plot(fpr3, tpr3, color='darkblack', lw=2, label='ROC curve3')
#plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
#plt.xlabel('False Positive Rate')
#plt.ylabel('True Positive Rate')
#plt.title('Receiver Operating Characteristic (ROC) Curve')
#plt.legend(loc='lower right')
#plt.show()


#print(f"AUC (Area Under the ROC Curve): {roc_auc:.2f}")
##print(f"AUC (Area Under the ROC Curve): {roc_auc1:.2f}")
###print(f"AUC (Area Under the ROC Curve): {roc_auc2:.2f}")
####print(f"AUC (Area Under the ROC Curve): {roc_auc3:.2f}")

# %% [markdown]
# ## bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# make pipeline (tdidf+logistic regression)
pipe = make_pipeline(CountVectorizer(),
                    LogisticRegression())

# make param grid
param_grid = {'logisticregression__C': [0.01, 0.1, 1, 10, 100]}

# create and fit the model
model = GridSearchCV(pipe, param_grid, cv=5)
model.fit(train_feature,train_target)

# make prediction and print accuracy
prediction = model.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy score is 0.88
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       443
#            1       0.89      0.87      0.88       439
#
#     accuracy                           0.88       882
#    macro avg       0.88      0.88      0.88       882
# weighted avg       0.88      0.88      0.88       882
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified aggressive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 47

# %%
len(aggressive_error)
# Out:
# 59

# %%
## make pipeline (Countvectorizer()+NB)


# Create a pipeline
pipe1 = make_pipeline(CountVectorizer(), MultinomialNB())

# Define the parameter grid
param_grid1 = {'multinomialnb__alpha': [0.01, 0.1, 1, 10, 100]}

# Create and fit the model using grid search
model1 = GridSearchCV(pipe1, param_grid1, cv=5)
model1.fit(train_feature, train_target)

# make prediction and print accuracy
prediction = model1.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# Accuracy score is 0.83
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82       443
#            1       0.79      0.89      0.84       439
#
#     accuracy                           0.83       882
#    macro avg       0.83      0.83      0.83       882
# weighted avg       0.83      0.83      0.83       882

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified aggressive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 104

# %%
len(aggressive_error)
# Out:
# 47

# %%
## make pipeline (Countvectorizer()+randomforest)

# Create the pipeline
pipe2 = make_pipeline(CountVectorizer(), RandomForestClassifier())

param_grid2 = {
    'randomforestclassifier__n_estimators': [100, 200, 300],
    'randomforestclassifier__max_depth': [None, 10, 20, 30]
}


# Create and fit the model using grid search
model2 = GridSearchCV(pipe2, param_grid2, cv=5)
model2.fit(train_feature, train_target)

# make prediction and print accuracy
prediction = model2.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# Accuracy score is 0.87
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       443
#            1       0.91      0.82      0.86       439
#
#     accuracy                           0.87       882
#    macro avg       0.87      0.87      0.87       882
# weighted avg       0.87      0.87      0.87       882

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified aggressive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 37

# %%
len(aggressive_error)
# Out:
# 81

# %%
#make pipeline (Countvectorizer()+SVM)

# Create a pipeline with CountVectorizer and LinearSVC
pipe3 = make_pipeline(CountVectorizer(), LinearSVC())

# Define the parameter grid for LinearSVC
param_grid3 = {'linearsvc__C': [0.01, 0.1, 1, 10, 100]}

# Create and fit the model using grid search
model3 = GridSearchCV(pipe3, param_grid3, cv=5)
model3.fit(train_feature, train_target)

# make prediction and print accuracy
prediction = model3.predict(test_feature)
print(f"Accuracy score is {accuracy_score(test_target, prediction):.2f}")
print(classification_report(test_target, prediction))
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Accuracy score is 0.87
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       443
#            1       0.88      0.86      0.87       439
#
#     accuracy                           0.87       882
#    macro avg       0.87      0.87      0.87       882
# weighted avg       0.87      0.87      0.87       882

# %%
#Error Analysis

# printing misclassified normal samples
test['Prediction'] = prediction
normal_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 0)]

# printing misclassified aggressive samples
test['Prediction'] = prediction
aggressive_error = test[(test['Prediction'] != test['Offensive']) & (test['Offensive'] == 1)]

# %%
len(normal_error)
# Out:
# 50

# %%
len(aggressive_error)
# Out:
# 61

# %% [markdown]
# # NGRAM
